# %% [markdown]
# # Chapter 11 — Backtesting and Evaluation
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter teaches rigorous evaluation methodology specific to NLP-based trading strategies. It addresses backtest overfitting, validation approaches, financial performance metrics, and common failure modes.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.evaluation import backtest, metrics

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 11.1 Walk-Forward Validation
#
# TODO: Implement walk-forward and expanding-window validation for time-series NLP signals.

# %% [markdown]
# ## 11.2 Financial Performance Metrics
#
# TODO: Calculate Sharpe ratio, maximum drawdown, Calmar ratio, and information ratio.

# %% [markdown]
# ## 11.3 NLP-Specific Evaluation
#
# TODO: Evaluate NLP model performance with financial-specific metrics and ablation studies.

# %% [markdown]
# ## 11.4 Common Failure Modes
#
# TODO: Identify and demonstrate backtest overfitting, survivorship bias, and look-ahead bias.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch11/`](../exercises/ch11/) for tiered exercises:
# - [Foundations](../exercises/ch11/foundations.md)
# - [Intermediate](../exercises/ch11/intermediate.md)
# - [Advanced](../exercises/ch11/advanced.md)
