# %% [markdown]
# # Chapter 9 — Entity Extraction and Financial Knowledge Graphs
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter moves beyond bag-of-sentiment to structured relational understanding of financial text. It covers financial NER, relation extraction, knowledge graph construction, and temporal knowledge graphs that track evolving relationships.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

from src.knowledge import entity_extraction, graph_builder

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 9.1 Financial Named Entity Recognition
#
# TODO: Build and evaluate NER models for financial entities (companies, people, monetary values).

# %% [markdown]
# ## 9.2 Relation Extraction from Filings
#
# TODO: Extract structured relationships (acquisitions, partnerships, lawsuits) from SEC filings.

# %% [markdown]
# ## 9.3 Knowledge Graph Construction
#
# TODO: Build a financial knowledge graph from extracted entities and relations.

# %% [markdown]
# ## 9.4 Temporal Graphs and Graph Features
#
# TODO: Construct temporal knowledge graphs and derive graph-based features for modeling.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch09/`](../exercises/ch09/) for tiered exercises:
# - [Foundations](../exercises/ch09/foundations.md)
# - [Intermediate](../exercises/ch09/intermediate.md)
# - [Advanced](../exercises/ch09/advanced.md)
