# %% [markdown]
# # Chapter 3 — NLP Foundations for Finance
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter establishes the NLP baseline so readers understand what transformers improved upon. It covers classical text processing methods and their specific applications in financial contexts, from bag-of-words and TF-IDF to word embeddings, making the case for when classical NLP remains the right choice.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 3.1 Tokenization and Document Representations
#
# TODO: Implement tokenization pipelines and bag-of-words/TF-IDF representations for financial text.

# %% [markdown]
# ## 3.2 Word Embeddings for Financial Text
#
# TODO: Train and evaluate Word2Vec/GloVe embeddings on financial corpora.

# %% [markdown]
# ## 3.3 Classical Sentiment Analysis
#
# TODO: Apply Loughran-McDonald dictionary and other lexicon-based approaches.

# %% [markdown]
# ## 3.4 Benchmarking Classical vs. Modern Approaches
#
# TODO: Compare classical NLP methods against transformer baselines on financial tasks.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch03/`](../exercises/ch03/) for tiered exercises:
# - [Foundations](../exercises/ch03/foundations.md)
# - [Intermediate](../exercises/ch03/intermediate.md)
# - [Advanced](../exercises/ch03/advanced.md)
