# %% [markdown]
# # Chapter 2 — Text Data Acquisition
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter provides a comprehensive guide to sourcing financial text data from SEC EDGAR, financial news APIs, earnings call transcripts, central bank communications, and social media. It covers the practical details of access methods, rate limits, and legal considerations, and builds a reliable data pipeline with deduplication and provenance tracking.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data import scrapers, loaders

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 2.1 SEC EDGAR: Structured Corporate Filings
#
# TODO: Demonstrate accessing and downloading SEC filings programmatically.

# %% [markdown]
# ## 2.2 Financial News and Earnings Call APIs
#
# TODO: Connect to news APIs and earnings call transcript providers.

# %% [markdown]
# ## 2.3 Social Media Data Sources
#
# TODO: Collect data from Reddit, Twitter/X, and StockTwits with rate-limit handling.

# %% [markdown]
# ## 2.4 Building a Data Pipeline with Provenance
#
# TODO: Build a unified pipeline with deduplication, timestamping, and provenance tracking.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch02/`](../exercises/ch02/) for tiered exercises:
# - [Foundations](../exercises/ch02/foundations.md)
# - [Intermediate](../exercises/ch02/intermediate.md)
# - [Advanced](../exercises/ch02/advanced.md)
