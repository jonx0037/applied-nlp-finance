# %% [markdown]
# # Chapter 13 — Risk, Ethics, and the Limits of Financial NLP
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter provides an honest treatment of what NLP cannot do and what it shouldn't do in financial markets. It covers model fragility, market manipulation, regulatory considerations, and systemic risk from correlated NLP strategies.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 13.1 Model Fragility and Tail Events
#
# TODO: Demonstrate how NLP models fail during market stress and regime changes.

# %% [markdown]
# ## 13.2 Market Manipulation via Language
#
# TODO: Analyze adversarial text attacks and manipulation vectors in financial NLP.

# %% [markdown]
# ## 13.3 Regulatory Landscape
#
# TODO: Survey regulatory frameworks relevant to NLP-driven financial systems.

# %% [markdown]
# ## 13.4 Systemic Risk and Ethics
#
# TODO: Examine systemic risks from correlated NLP strategies and ethical considerations.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch13/`](../exercises/ch13/) for tiered exercises:
# - [Foundations](../exercises/ch13/foundations.md)
# - [Intermediate](../exercises/ch13/intermediate.md)
# - [Advanced](../exercises/ch13/advanced.md)
