# %% [markdown]
# # Chapter 5 — Sentiment Analysis and Signal Construction
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter bridges the gap between model output and tradeable signal. It covers temporal aggregation, signal normalization, cross-asset sentiment effects, and multi-modal feature fusion, with a focus on production-grade signal engineering that avoids look-ahead bias.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.models import signal_builder

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 5.1 Temporal Aggregation of Sentiment Scores
#
# TODO: Implement rolling and event-based aggregation of raw sentiment scores.

# %% [markdown]
# ## 5.2 Signal Normalization and Regime Conditioning
#
# TODO: Apply z-scoring, percentile ranking, and regime-conditional normalization.

# %% [markdown]
# ## 5.3 Multi-Modal Feature Fusion
#
# TODO: Combine sentiment signals with price, volume, and volatility features.

# %% [markdown]
# ## 5.4 Look-Ahead Bias Prevention
#
# TODO: Demonstrate common look-ahead bias pitfalls and how to avoid them.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch05/`](../exercises/ch05/) for tiered exercises:
# - [Foundations](../exercises/ch05/foundations.md)
# - [Intermediate](../exercises/ch05/intermediate.md)
# - [Advanced](../exercises/ch05/advanced.md)
