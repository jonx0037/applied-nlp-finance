# %% [markdown]
# # Chapter 7 — Central Bank Language and Macro Signals
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter tackles the most market-moving scheduled text events in finance — central bank communications. It covers FOMC statement analysis, hawkish/dovish language models, and cross-central bank comparative analysis.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data import scrapers

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 7.1 Parsing FOMC Statements and Minutes
#
# TODO: Scrape and parse FOMC statements, minutes, and press conference transcripts.

# %% [markdown]
# ## 7.2 Hawkish/Dovish Language Index
#
# TODO: Build a hawkish-dovish scoring model for central bank language.

# %% [markdown]
# ## 7.3 Cross-Central Bank Analysis
#
# TODO: Compare language patterns across the Fed, ECB, BoE, and BoJ.

# %% [markdown]
# ## 7.4 Macro Nowcasting from Language
#
# TODO: Use central bank language features for economic nowcasting.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch07/`](../exercises/ch07/) for tiered exercises:
# - [Foundations](../exercises/ch07/foundations.md)
# - [Intermediate](../exercises/ch07/intermediate.md)
# - [Advanced](../exercises/ch07/advanced.md)
