# %% [markdown]
# # Chapter 12 — Deployment and Production Systems
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter closes the gap between research notebook and production pipeline. It covers batch and streaming NLP architectures, model serving with FastAPI, vector databases, RAG patterns, and infrastructure concerns.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from fastapi import FastAPI

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 12.1 Batch vs. Streaming NLP Pipelines
#
# TODO: Architect batch and streaming pipelines for financial text processing.

# %% [markdown]
# ## 12.2 Model Serving with FastAPI
#
# TODO: Build a FastAPI service for real-time sentiment scoring.

# %% [markdown]
# ## 12.3 Vector Databases and RAG
#
# TODO: Implement retrieval-augmented generation for financial document Q&A.

# %% [markdown]
# ## 12.4 Monitoring and Drift Detection
#
# TODO: Set up model monitoring, data drift detection, and alerting for production NLP systems.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch12/`](../exercises/ch12/) for tiered exercises:
# - [Foundations](../exercises/ch12/foundations.md)
# - [Intermediate](../exercises/ch12/intermediate.md)
# - [Advanced](../exercises/ch12/advanced.md)
