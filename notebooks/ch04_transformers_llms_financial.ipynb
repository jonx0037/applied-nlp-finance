# %% [markdown]
# # Chapter 4 — Transformers, LLMs, and Financial Language Models
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter provides deep treatment of transformer architecture and modern LLM workflows in the financial domain. It covers domain-adapted models like FinBERT and BloombergGPT, fine-tuning strategies, and LLM-based workflows including zero-shot classification, structured extraction, and agentic pipelines.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.models import finbert, llm_prompting
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 4.1 FinBERT and Domain-Adapted Models
#
# TODO: Load and evaluate FinBERT on financial sentiment classification tasks.

# %% [markdown]
# ## 4.2 Fine-Tuning on Custom Financial Corpora
#
# TODO: Demonstrate fine-tuning workflows with domain-specific datasets.

# %% [markdown]
# ## 4.3 LLM-Based Financial Workflows
#
# TODO: Build zero-shot classification, structured extraction, and agentic pipelines.

# %% [markdown]
# ## 4.4 Choosing the Right Model
#
# TODO: Compare model trade-offs across latency, cost, accuracy, and interpretability.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch04/`](../exercises/ch04/) for tiered exercises:
# - [Foundations](../exercises/ch04/foundations.md)
# - [Intermediate](../exercises/ch04/intermediate.md)
# - [Advanced](../exercises/ch04/advanced.md)
