# %% [markdown]
# # Chapter 1 — Why Text Moves Markets
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter makes the conceptual case for financial NLP before a single line of code is written. It establishes why financial markets are narrative-driven systems and how natural language processing has matured enough to systematically extract signal from financial text. The chapter provides the intellectual foundation for everything that follows.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 1.1 The Efficient Market Hypothesis and Information
#
# TODO: Demonstrate the relationship between information arrival and price changes.

# %% [markdown]
# ## 1.2 Historical Examples: Text Moving Markets
#
# TODO: Visualize concrete cases of text events and market reactions.

# %% [markdown]
# ## 1.3 A Taxonomy of Financial Text Data
#
# TODO: Construct the structured/unstructured × scheduled/unscheduled taxonomy.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch01/`](../exercises/ch01/) for tiered exercises:
# - [Foundations](../exercises/ch01/foundations.md)
# - [Intermediate](../exercises/ch01/intermediate.md)
# - [Advanced](../exercises/ch01/advanced.md)
