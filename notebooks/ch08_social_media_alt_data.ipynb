# %% [markdown]
# # Chapter 8 — Social Media and Alternative Text Data
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter handles noisier, higher-frequency, and legally complex text sources. It uses Reddit's WallStreetBets as a case study in separating signal from noise and covers bot detection, data quality filtering, and crypto social media analysis.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data import scrapers, preprocessing

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 8.1 Reddit WallStreetBets Case Study
#
# TODO: Collect and analyze WSB posts, measuring sentiment and attention metrics.

# %% [markdown]
# ## 8.2 Bot Detection and Quality Filtering
#
# TODO: Implement heuristic and ML-based bot detection for social media data.

# %% [markdown]
# ## 8.3 News vs. Social Media Momentum
#
# TODO: Compare the predictive power of news sentiment versus social media momentum.

# %% [markdown]
# ## 8.4 Crypto Social Media Analysis
#
# TODO: Analyze crypto-specific text sources (Crypto Twitter, Telegram, Discord).

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch08/`](../exercises/ch08/) for tiered exercises:
# - [Foundations](../exercises/ch08/foundations.md)
# - [Intermediate](../exercises/ch08/intermediate.md)
# - [Advanced](../exercises/ch08/advanced.md)
