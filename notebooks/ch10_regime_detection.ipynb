# %% [markdown]
# # Chapter 10 — Market Regime Detection
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter presents the author's primary research contribution — sentiment-based market regime detection. Building on the pipelines from Chapters 6–9, it constructs a cross-asset sentiment regime detector with real-world case studies.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.models import regime_detector, signal_builder

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 10.1 Quantitative Regime Detection Baseline
#
# TODO: Implement HMM and threshold-based regime detection as baselines.

# %% [markdown]
# ## 10.2 Sentiment Regime Detector Architecture
#
# TODO: Build the sentiment-enhanced regime detection model architecture.

# %% [markdown]
# ## 10.3 Multi-Modal Regime Features
#
# TODO: Combine text, price, and macro features for regime classification.

# %% [markdown]
# ## 10.4 Case Studies: COVID, Rate Hikes, Crypto
#
# TODO: Apply the regime detector to real-world market events and evaluate performance.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch10/`](../exercises/ch10/) for tiered exercises:
# - [Foundations](../exercises/ch10/foundations.md)
# - [Intermediate](../exercises/ch10/intermediate.md)
# - [Advanced](../exercises/ch10/advanced.md)
