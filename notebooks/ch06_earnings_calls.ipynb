# %% [markdown]
# # Chapter 6 — Earnings Calls and Corporate Disclosure
#
# **Applied NLP for Finance: Building Market Intelligence Systems with Language Models**
#
# *Jonathan Rocha*

# %% [markdown]
# ## Chapter Summary
#
# This chapter systematically analyzes scheduled, high-signal financial language events. It covers the structure of earnings calls, linguistic features predictive of post-earnings drift, and NLP approaches to 10-K/10-Q risk factor analysis.

# %% [markdown]
# ## Setup
#
# ```bash
# # One-time setup (run in terminal):
# # pip install -e ".[notebooks]"
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data import scrapers, preprocessing

# Set plotting defaults
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %% [markdown]
# ## 6.1 Parsing Earnings Call Transcripts
#
# TODO: Parse raw earnings call transcripts into structured sections (prepared remarks, Q&A).

# %% [markdown]
# ## 6.2 Linguistic Feature Extraction
#
# TODO: Extract linguistic features predictive of post-earnings drift.

# %% [markdown]
# ## 6.3 Risk Factor Analysis (10-K/10-Q)
#
# TODO: Analyze changes in risk factor disclosures across filing periods.

# %% [markdown]
# ## 6.4 Event Study Methodology
#
# TODO: Implement event study framework for measuring text-driven market reactions.

# %% [markdown]
# ---
#
# ## Exercises
#
# See [`../exercises/ch06/`](../exercises/ch06/) for tiered exercises:
# - [Foundations](../exercises/ch06/foundations.md)
# - [Intermediate](../exercises/ch06/intermediate.md)
# - [Advanced](../exercises/ch06/advanced.md)
